# %%
import pandas as pd

# %%
# import dataset
df_2018 = pd.read_csv("./surveys/OSMI 2018 Mental Health Survey.csv")

# %%
pd.set_option('display.max_columns', 125)
df_2018
# Out:
#                                     #  \
# 0    e44a0a34f2465940beda2a1537e9b99e
# 1    0d698e3beca20fb75f19b9d528e36d73
# 2    61a40c9071eb36fa9caa254d31500c41
# 3    f8624340bead7deb08abb766704ddf6b
# 4    31d3ae93b68d79e504a0a643601b6b1e
# ..                                ...
# 412  c7361d89328419b71ccd5f7cae16c818
# 413  c27be4d2a1eb40757e5be080a68b4ca9
# 414  b7bd8db00348415e1e9df49129290e31
# 415  d0a97741b04f1887f43c23839200a195
# 416  2f601b517e25f2623c6c1e415ea079c8
#
#      <strong>Are you self-employed?</strong>  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
# ..                                       ...
# 412                                        0
# 413                                        0
# 414                                        0
# ...

# %% [markdown]
# # 2021 survey

# %%
# select important columns
df_2021 = df[[
    'What is your age?',
    'What is your gender?', 
    'Do you *currently* have a mental health disorder?',
    'Have you ever been *diagnosed* with a mental health disorder?',
    'Have you ever sought treatment for a mental health disorder from a mental health professional?',
    'Do you have a family history of mental illness?',
    'Have you had a mental health disorder in the past?'
]]

# %%
df1
# Out:
#      What is your age? What is your gender?  \
# 0                   28               Female
# 1                   41                 male
# 2                   35                 Male
# 3                   20                 male
# 4                   35               female
# ..                 ...                  ...
# 126                 33                 Male
# 127                 49                 Male
# 128                 28                  NaN
# 129                 26                 Male
# 130                 38                 male
#
#     Do you *currently* have a mental health disorder?  \
# 0                                            Possibly
# 1                                                  No
# 2                                                  No
# 3                                          Don't Know
# 4                                                  No
# ..                                                ...
# ...

# %% [markdown]
# # 2020 survey

# %%
df_2020_selected_rows = df_2020[[
    'What is your age?',
    'What is your gender?', 
    'Do you *currently* have a mental health disorder?',
    'Have you ever been *diagnosed* with a mental health disorder?',
    'Have you ever sought treatment for a mental health disorder from a mental health professional?',
    'Do you have a family history of mental illness?',
    'Have you had a mental health disorder in the past?'
]]

# %%
df_2020_selected_rows
# Out:
#      What is your age? What is your gender?  \
# 0                   45                 Male
# 1                   24               female
# 2                   46                 Male
# 3                   25               Female
# 4                   25                    F
# ..                 ...                  ...
# 175                 53                 Male
# 176                 23                    F
# 177                 34                 Male
# 178                 43                 Male
# 179                 37                 male
#
#     Do you *currently* have a mental health disorder?  \
# 0                                          Don't Know
# 1                                                 Yes
# 2                                                 Yes
# 3                                                 Yes
# 4                                          Don't Know
# ..                                                ...
# ...

# %% [markdown]
# # 2019 survey

# %%
df_2019_selected_rows = df_2019[[
    'What is your age?',
    'What is your gender?', 
    'Do you *currently* have a mental health disorder?',
    'Have you ever been *diagnosed* with a mental health disorder?',
    'Have you ever sought treatment for a mental health disorder from a mental health professional?',
    'Do you have a family history of mental illness?',
    'Have you had a mental health disorder in the past?'
]]

# %%
df_2019_selected_rows
# Out:
#      What is your age? What is your gender?  \
# 0                   25                 Male
# 1                   51                 male
# 2                   27                 Male
# 3                   37                 male
# 4                   46                    m
# ..                 ...                  ...
# 347                 27                 male
# 348                 48                    m
# 349                 50                    M
# 350                 30               female
# 351                 24         Female (cis)
#
#     Do you *currently* have a mental health disorder?  \
# 0                                          Don't Know
# 1                                            Possibly
# 2                                                  No
# 3                                                  No
# 4                                                  No
# ..                                                ...
# ...

# %% [markdown]
# # 2018 survey

# %%
df_2018_selected_rows = df_2018[[
    'What is your age?',
    'What is your gender?', 
    'Do you currently have a mental health disorder?',
    'Have you ever been diagnosed with a mental health disorder?',
    'Have you ever sought treatment for a mental health disorder from a mental health professional?',
    'Do you have a family history of mental illness?',
    'Have you had a mental health disorder in the past?'
]]

# %%
df_2018_selected_rows
# Out:
#      What is your age? What is your gender?  \
# 0                   57               Female
# 1                   29                 male
# 2                   46                 Male
# 3                   34                 male
# 4                   29      Ostensibly Male
# ..                 ...                  ...
# 412                 28                 Male
# 413                 39                 Male
# 414                 31                 Male
# 415                 27                 Male
# 416                 35                 Male
#
#     Do you currently have a mental health disorder?  \
# 0                                          Possibly
# 1                                               Yes
# 2                                                No
# 3                                                No
# 4                                               Yes
# ..                                              ...
# 412                                              No
# ...

# %% [markdown]
# # 2017 survey

# %%
df_2017_selected_rows = df_2017[[
    'What is your age?',
    'What is your gender?', 
    'Do you currently have a mental health disorder?',
    'Have you ever been diagnosed with a mental health disorder?',
    'Have you ever sought treatment for a mental health disorder from a mental health professional?',
    'Do you have a family history of mental illness?',
    'Have you had a mental health disorder in the past?'
]]

# %%
df_2017_selected_rows
# Out:
#      What is your age? What is your gender?  \
# 0                 27.0               Female
# 1                 31.0                 male
# 2                 36.0                 male
# 3                 22.0                 Male
# 4                 52.0               female
# ..                 ...                  ...
# 751               41.0                 Male
# 752               40.0                 Male
# 753                NaN                  NaN
# 754               30.0                 dude
# 755                NaN                  NaN
#
#     Do you currently have a mental health disorder?  \
# 0                                          Possibly
# 1                                          Possibly
# 2                                               Yes
# 3                                               Yes
# 4                                                No
# ..                                              ...
# 751                                              No
# ...

# %% [markdown]
# # 2016 survey

# %%
df_2016_selected_rows = df_2016[[
    'What is your age?',
    'What is your gender?', 
    'Do you currently have a mental health disorder?',
    'Have you been diagnosed with a mental health condition by a medical professional?',
    'Have you ever sought treatment for a mental health issue from a mental health professional?',
    'Do you have a family history of mental illness?',
    'Have you had a mental health disorder in the past?'
]]

# %%
df_2016_selected_rows
# Out:
#       What is your age? What is your gender?  \
# 0                    39                 Male
# 1                    29                 male
# 2                    38                Male
# 3                    43                 male
# 4                    43               Female
# ...                 ...                  ...
# 1428                 34              Female
# 1429                 56                 MALE
# 1430                 52                 Male
# 1431                 30               Female
# 1432                 25           non-binary
#
#      Do you currently have a mental health disorder?  \
# 0                                                 No
# 1                                                Yes
# 2                                                 No
# 3                                                Yes
# 4                                                Yes
# ...                                              ...
# ...

# %% [markdown]
# # Renaming columns

# %%
df_2016_selected_rows.rename(columns={
    'Do you currently have a mental health disorder?': 'Do you *currently* have a mental health disorder?', 
    'Have you been diagnosed with a mental health condition by a medical professional?': 'Have you ever been *diagnosed* with a mental health disorder?',
    'Have you ever sought treatment for a mental health issue from a mental health professional?': 'Have you ever sought treatment for a mental health disorder from a mental health professional?'
    }
    , inplace=True
)
# Out:
# <ipython-input-108-73e6a9fd9cff>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2016_selected_rows.rename(columns={

# %%
df_2016_selected_rows
# Out:
#       What is your age? What is your gender?  \
# 0                    39                 Male
# 1                    29                 male
# 2                    38                Male
# 3                    43                 male
# 4                    43               Female
# ...                 ...                  ...
# 1428                 34              Female
# 1429                 56                 MALE
# 1430                 52                 Male
# 1431                 30               Female
# 1432                 25           non-binary
#
#      Do you *currently* have a mental health disorder?  \
# 0                                                   No
# 1                                                  Yes
# 2                                                   No
# 3                                                  Yes
# 4                                                  Yes
# ...                                                ...
# ...

# %%
df_2017_selected_rows.rename(columns={
    'Do you currently have a mental health disorder?': 'Do you *currently* have a mental health disorder?', 
    'Have you ever been diagnosed with a mental health disorder?': 'Have you ever been *diagnosed* with a mental health disorder?',
    }
    , inplace=True
)
# Out:
# <ipython-input-114-802d9582bad7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2017_selected_rows.rename(columns={

# %%
df_2017_selected_rows
# Out:
#      What is your age? What is your gender?  \
# 0                 27.0               Female
# 1                 31.0                 male
# 2                 36.0                 male
# 3                 22.0                 Male
# 4                 52.0               female
# ..                 ...                  ...
# 751               41.0                 Male
# 752               40.0                 Male
# 753                NaN                  NaN
# 754               30.0                 dude
# 755                NaN                  NaN
#
#     Do you *currently* have a mental health disorder?  \
# 0                                            Possibly
# 1                                            Possibly
# 2                                                 Yes
# 3                                                 Yes
# 4                                                  No
# ..                                                ...
# ...

# %%
df_2018_selected_rows.rename(columns={
    'Do you currently have a mental health disorder?': 'Do you *currently* have a mental health disorder?', 
    'Have you ever been diagnosed with a mental health disorder?': 'Have you ever been *diagnosed* with a mental health disorder?',
    }
    , inplace=True
)
# Out:
# <ipython-input-120-81f0110b2586>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018_selected_rows.rename(columns={

# %%
df_2018_selected_rows
# Out:
#      What is your age? What is your gender?  \
# 0                   57               Female
# 1                   29                 male
# 2                   46                 Male
# 3                   34                 male
# 4                   29      Ostensibly Male
# ..                 ...                  ...
# 412                 28                 Male
# 413                 39                 Male
# 414                 31                 Male
# 415                 27                 Male
# 416                 35                 Male
#
#     Do you *currently* have a mental health disorder?  \
# 0                                            Possibly
# 1                                                 Yes
# 2                                                  No
# 3                                                  No
# 4                                                 Yes
# ..                                                ...
# ...

# %% [markdown]
# # Concatenating dataframes

# %%
df_frames = [df_2019_selected_rows, df_2020_selected_rows, df_2021]

# %%
df_19_20_21 = pd.concat(df_frames)

# %%
df_19_20_21
# Out:
#      What is your age? What is your gender?  \
# 0                   25                 Male
# 1                   51                 male
# 2                   27                 Male
# 3                   37                 male
# 4                   46                    m
# ..                 ...                  ...
# 126                 33                 Male
# 127                 49                 Male
# 128                 28                  NaN
# 129                 26                 Male
# 130                 38                 male
#
#     Do you *currently* have a mental health disorder?  \
# 0                                          Don't Know
# 1                                            Possibly
# 2                                                  No
# 3                                                  No
# 4                                                  No
# ..                                                ...
# ...

# %%
df_frames_2 = [df_2016_selected_rows, df_2017_selected_rows, df_2018_selected_rows]

# %%
df_16_17_18 = pd.concat(df_frames_2)

# %%
df_16_17_18
# Out:
#      What is your age? What is your gender?  \
# 0                 39.0                 Male
# 1                 29.0                 male
# 2                 38.0                Male
# 3                 43.0                 male
# 4                 43.0               Female
# ..                 ...                  ...
# 412               28.0                 Male
# 413               39.0                 Male
# 414               31.0                 Male
# 415               27.0                 Male
# 416               35.0                 Male
#
#     Do you *currently* have a mental health disorder?  \
# 0                                                  No
# 1                                                 Yes
# 2                                                  No
# 3                                                 Yes
# 4                                                 Yes
# ..                                                ...
# ...

# %%
df_frames_all = [df_16_17_18, df_19_20_21]
df_complete = pd.concat(df_frames_all)

# %%
df_complete
# Out:
#      What is your age? What is your gender?  \
# 0                 39.0                 Male
# 1                 29.0                 male
# 2                 38.0                Male
# 3                 43.0                 male
# 4                 43.0               Female
# ..                 ...                  ...
# 126               33.0                 Male
# 127               49.0                 Male
# 128               28.0                  NaN
# 129               26.0                 Male
# 130               38.0                 male
#
#     Do you *currently* have a mental health disorder?  \
# 0                                                  No
# 1                                                 Yes
# 2                                                  No
# 3                                                 Yes
# 4                                                 Yes
# ..                                                ...
# ...

# %%
df_complete.to_csv("mental_health_data_2016-2021.csv")
