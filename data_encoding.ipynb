# %%
# import libraries
import pandas as pd
from sklearn import metrics
from sklearn.model_selection import train_test_split
import lightgbm as ltb
import xgboost as xgb
import catboost as catb
import matplotlib.pyplot as plt

# %%
# import dataset
df = pd.read_csv("./combined_surveys_2016-2021/mental_health_data_2016-2021.csv")
df.head(3)
# Out:
#    Unnamed: 0   age    sex  self-employed           working_country  \
# 0           0  39.0   Male              0            United Kingdom
# 1           1  29.0   male              0  United States of America
# 2           2  38.0  Male               0            United Kingdom
#
#              living_country mental_illness_family_history have_mental_illness  \
# 0            United Kingdom                            No                  No
# 1  United States of America                           Yes                 Yes
# 2            United Kingdom                            No                  No
#
#   mental_disorder_in_the_past number_of_employees_your_company_has  \
# 0                         Yes                               26-100
# 1                         Yes                                 6-25
# 2                       Maybe                                 6-25
#
#   mental_health_benefits_from_previous_employers mental_illness_diagnosis  \
# 0                                   No, none did                      Yes
# 1                              Yes, they all did                      Yes
# 2                                   No, none did                       No
#
#   mental_health_benefits_from_current_employer  \
# 0              Not eligible for coverage / N/A
# 1                                           No
# 2                                           No
#
#   discussing_mental_health_with_coworkers  sought_mental_treatment  \
# 0                                   Maybe                        0
# 1                                   Maybe                        1
# 2                                   Maybe                        1
#
#   discussing_mental_health_with_supervisor mental_illness_medical_coverage
# 0                                      Yes                             NaN
# 1                                      Yes                             NaN
# 2                                    Maybe                             NaN

# %% [markdown]
# ## Grouping

# %%
# Grouping Countries (for working_country & living_country columns)
europe = ['Luxembourg', 'Latvia', 'Belarus', 'Albania', 'Lithuania', 'Croatia', 'Bosnia and Herzegovina', 
          'Hungary', 'Slovakia', 'Iceland', 'Ukraine', 'Czech Republic', 'Serbia', 'Macedonia', 
          'Greece', 'Estonia', 'Denmark', 'Slovenia', 'Romania', 'Austria', 'Belgium', 'Bulgaria', 
          'Norway', 'Finland', 'Italy', 'Poland', 'Switzerland', 'Portugal', 'Sweden', 'Ireland', 
          'Spain', 'France', 'Netherlands', 'Germany', 'United Kingdom']

asia = ['Iran', 'Jordan', 'Singapore', 'Saudi Arabia', 'Georgia', 'Taiwan', 'Egypt', 'Malaysia', 'Brunei', 
        'United Arab Emirates', 'Mongolia', 'Hong Kong', 'China', 'Sri Lanka', 'Vietnam', 'Philippines', 
       'Afghanistan', 'Bangladesh', 'Israel', 'Japan', 'Pakistan', 'Indonesia', 'Turkey', 'Russia', 'India']

north_america = ['Mexico', 'Canada', 'United States of America']

south_america = ['Ecuador', 'Guatemala', 'Uruguay', 'Costa Rica', 'Venezuela', 'Kenya', 
                 'Nigeria', 'Argentina', 'Chile', 'Colombia', 'Brazil']

africa = ['Eritrea', 'Swaziland', 'Mauritius', 'Ethiopia', 'Ghana', 
          'Botswana', 'Algeria', 'Cameroon', 'Kenya', 'South Africa', 'Sao Tome and Principe']

australia = ['New Zealand', 'Australia']

# %%
pd.set_option("display.max_rows", None)
df['working_country'].value_counts(ascending=True)
# Out:
# Iran                           1
# Ecuador                        1
# Guatemala                      1
# Jordan                         1
# Eritrea                        1
# Swaziland                      1
# Singapore                      1
# Luxembourg                     1
# Latvia                         1
# Mauritius                      1
# Saudi Arabia                   1
# Uruguay                        1
# Ethiopia                       1
# Georgia                        1
# Ghana                          1
# Botswana                       1
# Algeria                        1
# Cameroon                       1
# Taiwan                         1
# Egypt                          1
# Malaysia                       1
# Belarus                        1
# Brunei                         1
# Costa Rica                     1
# Albania                        1
# Venezuela                      1
# Lithuania                      1
# United Arab Emirates           1
# Kenya                          2
# Nigeria                        2
# Mongolia                       2
# Croatia                        2
# Hong Kong                      2
# Bosnia and Herzegovina         2
# Hungary                        2
# China                          2
# Sri Lanka                      2
# Vietnam                        2
# Slovakia                       2
# Philippines                    3
# Other                          3
# Argentina                      3
# Chile                          3
# Iceland                        3
# Ukraine                        3
# Afghanistan                    4
# Czech Republic                 4
# Serbia                         5
# Bangladesh                     5
# Macedonia                      5
# Greece                         5
# Colombia                       6
# Estonia                        6
# Israel                         6
# Japan                          6
# Pakistan                       7
# Denmark                        7
# Indonesia                      7
# Slovenia                       7
# Romania                        7
# Austria                        9
# Turkey                         9
# Belgium                        9
# Bulgaria                      10
# Mexico                        10
# Norway                        11
# Finland                       12
# Italy                         13
# South Africa                  13
# Russia                        15
# Poland                        16
# New Zealand                   16
# Switzerland                   23
# Portugal                      24
# Sweden                        25
# Ireland                       25
# Spain                         30
# France                        36
# Brazil                        45
# Australia                     57
# Netherlands                   77
# India                         92
# Germany                      103
# Canada                       135
# United Kingdom               309
# United States of America    1988
# Name: working_country, dtype: int64

# %%
country_columns = ['working_country', 'living_country']
for column_name in country_columns:
    for value in df[column_name]:
        if value in europe:
            df[column_name].replace(value, 'europe', inplace=True)
        elif value in asia:
            df[column_name].replace(value, 'asia', inplace=True)
        elif value in north_america:
            df[column_name].replace(value, 'north_america', inplace=True)
        elif value in south_america:
            df[column_name].replace(value, 'south_america', inplace=True)
        elif value in africa:
            df[column_name].replace(value, 'africa', inplace=True)
        elif value in australia:
            df[column_name].replace(value, 'australia', inplace=True)

# %%
print(df['working_country'].value_counts(ascending=True))
print(df['living_country'].value_counts(ascending=True))
# Out:
# Other               3
# africa             21
# south_america      66
# australia          73
# asia              174
# europe            797
# north_america    2133
# Name: working_country, dtype: int64
# Other               2
# africa             20
# south_america      69
# australia          74
# asia              179
# europe            807
# north_america    2116
# Name: living_country, dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0   age     sex  self-employed working_country living_country  \
# 0           0  39.0    Male              0          europe         europe
# 1           1  29.0    male              0   north_america  north_america
# 2           2  38.0   Male               0          europe         europe
# 3           3  43.0    male              1          europe         europe
# 4           4  43.0  Female              0   north_america  north_america
#
#   mental_illness_family_history have_mental_illness  \
# 0                            No                  No
# 1                           Yes                 Yes
# 2                            No                  No
# 3                            No                 Yes
# 4                           Yes                 Yes
#
#   mental_disorder_in_the_past number_of_employees_your_company_has  \
# 0                         Yes                               26-100
# 1                         Yes                                 6-25
# 2                       Maybe                                 6-25
# 3                         Yes                                  NaN
# 4                         Yes                                 6-25
#
#   mental_health_benefits_from_previous_employers mental_illness_diagnosis  \
# 0                                   No, none did                      Yes
# 1                              Yes, they all did                      Yes
# 2                                   No, none did                       No
# 3                                       Some did                      Yes
# 4                                   I don't know                      Yes
#
#   mental_health_benefits_from_current_employer  \
# 0              Not eligible for coverage / N/A
# 1                                           No
# 2                                           No
# 3                                          NaN
# 4                                          Yes
#
#   discussing_mental_health_with_coworkers  sought_mental_treatment  \
# 0                                   Maybe                        0
# 1                                   Maybe                        1
# 2                                   Maybe                        1
# 3                                     NaN                        1
# 4                                   Maybe                        1
#
#   discussing_mental_health_with_supervisor mental_illness_medical_coverage
# 0                                      Yes                             NaN
# 1                                      Yes                             NaN
# 2                                    Maybe                             NaN
# 3                                      NaN                             1.0
# 4                                       No                             NaN

# %%
# Grouping age column and creating age-range column

for value in df['age']:
    if value < 0:
        pass
    elif value <= 10:
        df['age'].replace(value, 'child', inplace=True)
    elif value <= 20:
        df['age'].replace(value, 'teenager', inplace=True)
    elif value <= 30:
        df['age'].replace(value, 'adult', inplace=True)
    elif value <= 50:
        df['age'].replace(value, 'middle-aged', inplace=True)
    elif value <= 60:
        df['age'].replace(value, 'old', inplace=True)
    elif value > 60:
        df['age'].replace(value, 'very_old', inplace=True)

# %%
df['age'].value_counts()
# Out:
# middle-aged    1912
# adult          1162
# old             124
# teenager         34
# very_old         31
# child             4
# Name: age, dtype: int64
